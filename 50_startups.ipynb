# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyansh07/MLCOE-Task-2/blob/main/50_startups.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/50_Startups.csv')
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data.shape
# Out:
# (50, 5)

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      38.000000       32.000000        50.000000      50.000000
# mean    84471.755526   124460.951250    211025.097800  112012.639200
# std     47140.937802    24360.580496    122290.310726   40306.180338
# min         0.000000    51743.150000         0.000000   14681.400000
# 25%     65716.990000   113049.002500    129300.132500   90138.902500
# 50%     82404.585000   125604.625000    212716.240000  107978.190000
# 75%    120392.700000   145190.700000    299469.085000  139765.977500
# max    165349.200000   157693.920000    471784.100000  192261.830000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        38 non-null     float64
#  1   Administration   32 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
data.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
data.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %% [markdown]
# Check the Null values and Duplicate Values.

# %%
data.isnull().sum()
# Out:
# R&D Spend          12
# Administration     18
# Marketing Spend     0
# State               0
# Profit              0
# dtype: int64

# %%
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data.shape
# Out:
# (50, 5)

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %% [markdown]
# *There is no duplicated and null values.*

# %% [markdown]
# There are some values which are 0. Logically they cannot be zero.

# %% [markdown]
# #**DATA PREPROCESSING**

# %% [markdown]
# There are only 3 States from where the top 50 startups come i.e. New York, California and Florida.
# **These variables should be converted to numeric.**

# %%
data['State']=data['State'].replace({'New York':1,'California':2,'Florida':3})

# %%
data
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      1  192261.83
# 1   162597.70       151377.59        443898.53      2  191792.06
# 2   153441.51       101145.55        407934.54      3  191050.39
# 3   144372.41       118671.85        383199.62      1  182901.99
# 4   142107.34        91391.77        366168.42      3  166187.94
# 5   131876.90        99814.71        362861.36      1  156991.12
# 6   134615.46       147198.87        127716.82      2  156122.51
# 7   130298.13       145530.06        323876.68      3  155752.60
# 8   120542.52       148718.95        311613.29      1  152211.77
# 9   123334.88       108679.17        304981.62      2  149759.96
# 10  101913.08       110594.11        229160.95      3  146121.95
# 11  100671.96        91790.61        249744.55      2  144259.40
# 12   93863.75       127320.38        249839.44      3  141585.52
# ...

# %% [markdown]
# #DATA VISUALISATION

# %%
sns.pairplot(data)

# %%
data['State'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
data["State"].value_counts()
# Out:
# 1    17
# 2    17
# 3    16
# Name: State, dtype: int64

# %% [markdown]
# New York and California have 17 startups whereas Florida has 16 startups.

# %%
data.groupby('State')['Marketing Spend'].mean().reset_index()
# Out:
#    State  Marketing Spend
# 0      1    205346.015882
# 1      2    182540.929412
# 2      3    247323.551250
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['State'].plot(kind='hist', bins=20, title='State')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Marketing Spend'].plot(kind='hist', bins=20, title='Marketing Spend')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='State', y='Marketing Spend', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
# ...

# %%
corr = data.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #Normalising the Data
#
# We are converting the values in the scale of 0 and 1 in order to make it easy for running machine learning algorithm.

# %% [markdown]
# #Filling the Nan Values
#
# x is the list of the dependent variable whereas y is the list of indepenedent variable. There are various places which contains Nan places. Therefore that can be improved by skilearn through SimpleImputer which will take the mean of the column and compute the Nan value itself.

# %%
x=data[['R&D Spend', 'Administration', 'Marketing Spend', 'Profit']].values
x
# Out:
# array([[165349.2 , 136897.8 , 471784.1 , 192261.83],
#        [162597.7 , 151377.59, 443898.53, 191792.06],
#        [153441.51, 101145.55, 407934.54, 191050.39],
#        [144372.41, 118671.85, 383199.62, 182901.99],
#        [142107.34,  91391.77, 366168.42, 166187.94],
#        [131876.9 ,  99814.71, 362861.36, 156991.12],
#        [134615.46, 147198.87, 127716.82, 156122.51],
#        [130298.13, 145530.06, 323876.68, 155752.6 ],
#        [120542.52, 148718.95, 311613.29, 152211.77],
#        [123334.88, 108679.17, 304981.62, 149759.96],
#        [101913.08, 110594.11, 229160.95, 146121.95],
#        [100671.96,  91790.61, 249744.55, 144259.4 ],
#        [ 93863.75, 127320.38, 249839.44, 141585.52],
#        [ 91992.39, 135495.07, 252664.93, 134307.35],
#        [119943.24, 156547.42, 256512.92, 132602.65],
#        [114523.61, 122616.84, 261776.23, 129917.04],
#        [ 78013.11, 121597.55, 264346.06, 126992.93],
#        [ 94657.16, 145077.58, 282574.31, 125370.37],
# ...

# %%
y=data[['State']].values

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
imputer=imputer.fit(x[:,0:2])
x[:,0:2]=imputer.transform(x[:,0:2])

# %%
x
# Out:
# array([[165349.2       , 136897.8       , 471784.1       ,
#         192261.83      ],
#        [162597.7       , 151377.59      , 443898.53      ,
#         191792.06      ],
#        [153441.51      , 101145.55      , 407934.54      ,
#         191050.39      ],
#        [144372.41      , 118671.85      , 383199.62      ,
#         182901.99      ],
#        [142107.34      ,  91391.77      , 366168.42      ,
#         166187.94      ],
#        [131876.9       ,  99814.71      , 362861.36      ,
#         156991.12      ],
#        [134615.46      , 147198.87      , 127716.82      ,
#         156122.51      ],
#        [130298.13      , 145530.06      , 323876.68      ,
#         155752.6       ],
#        [120542.52      , 148718.95      , 311613.29      ,
#         152211.77      ],
#        [123334.88      , 108679.17      , 304981.62      ,
#         149759.96      ],
#        [101913.08      , 110594.11      , 229160.95      ,
#         146121.95      ],
# ...
