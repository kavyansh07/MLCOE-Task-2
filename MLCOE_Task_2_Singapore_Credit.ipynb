# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyansh07/MLCOE-Task-2/blob/main/MLCOE_Task_2_Singapore_Credit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/Raw_Data_Singapore Credit Dataset.csv')
data
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 0            < 0 SGD                     6       critical
# 1        1 - 200 SGD                    48           good
# 2            unknown                    12       critical
# 3            < 0 SGD                    42           good
# 4            < 0 SGD                    24           poor
# ..               ...                   ...            ...
# 995          unknown                    12           good
# 996          < 0 SGD                    30           good
# 997          unknown                    12           good
# 998          < 0 SGD                    45           good
# 999      1 - 200 SGD                    45       critical
#
#                   purpose  amount savings_balance employment_duration  \
# 0    furniture/appliances    1169         unknown           > 7 years
# 1    furniture/appliances    5951       < 100 SGD         1 - 4 years
# ...

# %%
data.shape
# Out:
# (1000, 17)

# %%
data.describe()
# Out:
#        months_loan_duration        amount  percent_of_income  \
# count           1000.000000   1000.000000        1000.000000
# mean              20.903000   3271.258000           2.973000
# std               12.058814   2822.736876           1.118715
# min                4.000000    250.000000           1.000000
# 25%               12.000000   1365.500000           2.000000
# 50%               18.000000   2319.500000           3.000000
# 75%               24.000000   3972.250000           4.000000
# max               72.000000  18424.000000           4.000000
#
#        years_at_residence          age  existing_loans_count   dependents
# count         1000.000000  1000.000000           1000.000000  1000.000000
# mean             2.845000    35.546000              1.407000     1.155000
# std              1.103718    11.375469              0.577654     0.362086
# min              1.000000    19.000000              1.000000     1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   checking_balance      1000 non-null   object
#  1   months_loan_duration  1000 non-null   int64
#  2   credit_history        1000 non-null   object
#  3   purpose               1000 non-null   object
#  4   amount                1000 non-null   int64
#  5   savings_balance       1000 non-null   object
#  6   employment_duration   1000 non-null   object
#  7   percent_of_income     1000 non-null   int64
#  8   years_at_residence    1000 non-null   int64
#  9   age                   1000 non-null   int64
#  10  other_credit          1000 non-null   object
#  11  housing               1000 non-null   object
#  12  existing_loans_count  1000 non-null   int64
#  13  job                   1000 non-null   object
#  14  dependents            1000 non-null   int64
# ...

# %%
data.head()
# Out:
#   checking_balance  months_loan_duration credit_history               purpose  \
# 0          < 0 SGD                     6       critical  furniture/appliances
# 1      1 - 200 SGD                    48           good  furniture/appliances
# 2          unknown                    12       critical             education
# 3          < 0 SGD                    42           good  furniture/appliances
# 4          < 0 SGD                    24           poor                   car
#
#    amount savings_balance employment_duration  percent_of_income  \
# 0    1169         unknown           > 7 years                  4
# 1    5951       < 100 SGD         1 - 4 years                  2
# 2    2096       < 100 SGD         4 - 7 years                  2
# 3    7882       < 100 SGD         4 - 7 years                  2
# 4    4870       < 100 SGD         1 - 4 years                  3
#
#    years_at_residence  age other_credit housing  existing_loans_count  \
# ...

# %%
data.tail()
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 995          unknown                    12           good
# 996          < 0 SGD                    30           good
# 997          unknown                    12           good
# 998          < 0 SGD                    45           good
# 999      1 - 200 SGD                    45       critical
#
#                   purpose  amount savings_balance employment_duration  \
# 995  furniture/appliances    1736       < 100 SGD         4 - 7 years
# 996                   car    3857       < 100 SGD         1 - 4 years
# 997  furniture/appliances     804       < 100 SGD           > 7 years
# 998  furniture/appliances    1845       < 100 SGD         1 - 4 years
# 999                   car    4576   100 - 500 SGD          unemployed
#
#      percent_of_income  years_at_residence  age other_credit housing  \
# 995                  3                   4   31         none     own
# ...

# %%
data.columns
# Out:
# Index(['checking_balance', 'months_loan_duration', 'credit_history', 'purpose',
#        'amount', 'savings_balance', 'employment_duration', 'percent_of_income',
#        'years_at_residence', 'age', 'other_credit', 'housing',
#        'existing_loans_count', 'job', 'dependents', 'phone', 'default'],
#       dtype='object')

# %%
data.dtypes
# Out:
# checking_balance        object
# months_loan_duration     int64
# credit_history          object
# purpose                 object
# amount                   int64
# savings_balance         object
# employment_duration     object
# percent_of_income        int64
# years_at_residence       int64
# age                      int64
# other_credit            object
# housing                 object
# existing_loans_count     int64
# job                     object
# dependents               int64
# phone                   object
# default                 object
# dtype: object

# %%
data.isnull().sum()
# Out:
# checking_balance        0
# months_loan_duration    0
# credit_history          0
# purpose                 0
# amount                  0
# savings_balance         0
# employment_duration     0
# percent_of_income       0
# years_at_residence      0
# age                     0
# other_credit            0
# housing                 0
# existing_loans_count    0
# job                     0
# dependents              0
# phone                   0
# default                 0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is not duplicated and null values.

# %%
sns.pairplot(data)

# %%
color=data["credit_history"].value_counts().plot(kind='pie')

# %% [markdown]
# Most of the people have good credit history but there are many who have critical credit history which is a point to be noted.

# %%
sns.violinplot(y='percent_of_income',x='job',hue='dependents',data=data,split=True)
plt.show()

# %% [markdown]
# There are maximum unemplyed people who have percent of income 2 and dependent 2.

# %%
sns.boxplot(
    x = "age",
    y = "amount",
    showmeans=True,
    data=data
)
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.kdeplot(x = 'age', data = data)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(x = 'amount', data = data)
# Out:
# <Axes: xlabel='amount', ylabel='Density'>

# %%
sns.countplot(x=data['phone'],data=data)
x_label='Phone'

# %%
sns.countplot(x=data['purpose'],data=data)
plt.xticks(rotation=45)
plt.xlabel('Purpose of taking credit')
plt.title('Purpose of taking credit')
plt.show()

# %%
data['credit_history'].replace({'critical':-1,'good':1,'poor':0,'perfect':3,'very good':2},inplace=True)
data
# Out:
#     checking_balance  months_loan_duration  credit_history  \
# 0            < 0 SGD                     6              -1
# 1        1 - 200 SGD                    48               1
# 2            unknown                    12              -1
# 3            < 0 SGD                    42               1
# 4            < 0 SGD                    24               0
# ..               ...                   ...             ...
# 995          unknown                    12               1
# 996          < 0 SGD                    30               1
# 997          unknown                    12               1
# 998          < 0 SGD                    45               1
# 999      1 - 200 SGD                    45              -1
#
#                   purpose  amount savings_balance employment_duration  \
# 0    furniture/appliances    1169         unknown           > 7 years
# 1    furniture/appliances    5951       < 100 SGD         1 - 4 years
# ...

# %%
sns.scatterplot(x=data.checking_balance, y=data.amount, hue=data.job)
# Out:
# <Axes: xlabel='checking_balance', ylabel='amount'>

# %%
data['employment_duration'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# There are maximum people who have employment duration between 1-4 years. Unemployed people takes less credit but takes.

# %%
corr = data.corr()
sns.heatmap(corr,annot=True)
# Out:
# <ipython-input-55-add5c5fe8e43>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# <Axes: >

# %%
data['checking_balance'].value_counts()
# Out:
# unknown        394
# < 0 SGD        274
# 1 - 200 SGD    269
# > 200 SGD       63
# Name: checking_balance, dtype: int64

# %%
ct1 = pd.crosstab(
    index=data['checking_balance'],
    columns=data['credit_history'],
    normalize='index'
)
ct1
# Out:
# credit_history          -1         0         1         2         3
# checking_balance
# 1 - 200 SGD       0.204461  0.130112  0.542751  0.055762  0.066914
# < 0 SGD           0.244526  0.043796  0.583942  0.080292  0.047445
# > 200 SGD         0.285714  0.047619  0.587302  0.047619  0.031746
# unknown           0.388325  0.096447  0.474619  0.022843  0.017766
